# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys,pandas,os
sys.path.append('/home/heyangle/Desktop/ScanCraft/ScanCraft')

# %% [markdown]
# # read one line

# %%
line=' 3 15. # tan beta\n'

# %%
import sys,argparse,os,pandas,numpy,copy
sys.path.append('/home/heyangle/Desktop/ScanCraft/ScanCraft')

# %%
from command.read.SLHA_string import SLHA_string

# %%
l1=SLHA_string(linimport sys,argparse,os,pandas,numpy,copy
sys.path.append('/home/heyangle/Desktop/ScanCraft/ScanCraft')e)

# %%
l1
# Out:
# ' 3 15. # tan beta\n'

# %%
l1.string
# Out:
# '3 15. '

# %%
l1.annotation
# Out:
# ' tan beta'

# %%
def pre(func):
    def _pre(s):
        n=func.__code__.co_argcount
        pars=s.split()[:n]
        if not len(pars)==n:
            return None
        print(n,'pars: ',pars)
        out=func(*pars)
        return out
    return _pre

# %%
@pre
def read(a,b):
    print(a,b)

# %%
read('1 2')
# Out:
# 2 pars:  ['1', '2']
# 1 2

# %%
a='block aaa1 '+'adfawerfwefawetweagtadfawerwerwe'*20
a
# Out:
# 'block aaa1 ...'

# %%
# %timeit a.upper().startswith('BLOCK')
# Out:
# 404 ns ± 4.45 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit 'BLOCK' in 'block aaa1'.upper()
# Out:
# 56.1 ns ± 0.929 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit 'BLOCK' in a.upper()
# Out:
# 357 ns ± 3.34 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit 'BLOCK' in a[:5].upper()
# Out:
# 92.2 ns ± 0.526 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit 'BLOCK' == 'block aaa1'[:5].upper()
# Out:
# 90.6 ns ± 1.64 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
'BLOCK' == 'block aaa1'[:5].upper()
# Out:
# True

# %% [markdown]
# # read full slha document

# %%
from command.DataProcessing.SLHA.SLHA_document import SLHA_document

# %%
spec=SLHA_document('./spectr.dat.10')

# %%
spec.text
# Out:
# ['# NMSSMTools OUTPUT IN SLHA FORMAT\n',
#  '# Info about spectrum calculator\n',
#  'BLOCK SPINFO   # Program information\n',
#  '     1   NMSSMTools # Spectrum calculator\n',
#  '     2   5.4.1      # Version number\n',
#  '     3   # Higgs soft masses >> Msusy\n',
#  '     3   # DM relic density too large\n',
#  '     3   # Muon magn. mom. more than 2 sigma away\n',
#  '     3   # No Higgs in the 122.1-128.1 GeV mass range\n',
#  '     3   # b -> c tau nu more than 2 sigma away (as SM)\n',
#  '     3   # k_bot(H_SM) more than 2 sigma away (as SM)\n',
#  '     3   # k_tau(H_SM) more than 2 sigma away (as SM)\n',
#  '# Input parameters\n',
#  'BLOCK MODSEL\n',
#  '  3  1   # NMSSM particle content\n',
#  '  1  0   # IMOD\n',
#  ' 10  0   # ISCAN\n',
#  '  9  1   # Call micrOmegas\n',
#  '  8  1   # Precision for Higgs masses\n',
#  ' 13  1   # Sparticle decays via NMSDECAY\n',
#  ' 14  1   # H-> VV,VV*,(V*V*)\n',
#  ' 15  0   # Precision for micromegas\n',
# ...

# %%
a='t'
b={a,1}

# %%
# Out:
# {1, 't'}

# %%
b[a]
# Out:
# 1
